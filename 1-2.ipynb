# %%
import pandas as pd

# %%
pd.DataFrame({'Yes':[50, 100], 'No':[37, 59]})
# Out:
#    Yes  No
# 0   50  37
# 1  100  59

# %%
datf = pd.DataFrame({'Yes':[50, 100], 'No':[37, 59]},
                   index = ['first', 'second'])

# %%
datf
# Out:
#         Yes  No
# first    50  37
# second  100  59

# %%
datf.to_csv("Examle.csv")

# %%
print(type(datf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Series

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([100, 137, 95], index = ['2020', '2021', '2022'], name = "Rate")
# Out:
# 2020    100
# 2021    137
# 2022     95
# Name: Rate, dtype: int64

# %%
app_reviews = pd.read_csv("C:/Users/User/.jupyter/googleplaystore.csv")

# %%
app_reviews
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
app_reviews.shape
# Out:
# (10841, 13)

# %%
app_reviews.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
app_reviews2 = pd.read_csv("C:/Users/User/.jupyter/googleplaystore.csv", index_col = 0)

# %%
app_reviews2
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %% [markdown]
# ### Indexing

# %%
app_reviews.App
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
app_reviews['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
app_reviews['App'][0]
# Out:
# 'Photo Editor & Candy Camera & Grid & ScrapBook'

# %% [markdown]
# ## iloc

# %%
app_reviews.iloc[0] #Row
# Out:
# App               Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                          ART_AND_DESIGN
# Rating                                                       4.1
# Reviews                                                      159
# Size                                                         19M
# Installs                                                 10,000+
# Type                                                        Free
# Price                                                          0
# Content Rating                                          Everyone
# Genres                                              Art & Design
# Last Updated                                     January 7, 2018
# Current Ver                                                1.0.0
# Android Ver                                         4.0.3 and up
# Name: 0, dtype: object

# %%
app_reviews.iloc[:3]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
app_reviews.iloc[:3, 0]
# Out:
# 0       Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                  Coloring book moana
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...
# Name: App, dtype: object

# %%
app_reviews.iloc[[0]]
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#   Reviews Size Installs  Type Price Content Rating        Genres  \
# 0     159  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %%
app_reviews.iloc[[0, 1]]
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
app_reviews.iloc[0, 1]
# Out:
# 'ART_AND_DESIGN'

# %%
app_reviews.iloc[::3, 4:]
# Out:
#                      Size     Installs  Type Price Content Rating  \
# 0                     19M      10,000+  Free     0       Everyone
# 3                     25M  50,000,000+  Free     0           Teen
# 6                     19M      50,000+  Free     0       Everyone
# 9                    3.1M      10,000+  Free     0       Everyone
# 12                    20M  10,000,000+  Free     0           Teen
# ...                   ...          ...   ...   ...            ...
# 10827                 13M       5,000+  Free     0       Everyone
# 10830                2.3M     100,000+  Free     0       Everyone
# 10833                619k       1,000+  Free     0       Everyone
# 10836                 53M       5,000+  Free     0       Everyone
# 10839  Varies with device       1,000+  Free     0     Mature 17+
#
#                         Genres      Last Updated         Current Ver  \
# 0                 Art & Design   January 7, 2018               1.0.0
# ...

# %%
app_reviews.iloc[[3, 4]]
# Out:
#                                      App        Category  Rating Reviews  \
# 3                  Sketch - Draw & Paint  ART_AND_DESIGN     4.5  215644
# 4  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3     967
#
#    Size     Installs  Type Price Content Rating                   Genres  \
# 3   25M  50,000,000+  Free     0           Teen             Art & Design
# 4  2.8M     100,000+  Free     0       Everyone  Art & Design;Creativity
#
#     Last Updated         Current Ver Android Ver
# 3   June 8, 2018  Varies with device  4.2 and up
# 4  June 20, 2018                 1.1  4.4 and up

# %%
app_reviews.iloc[3, 4]
# Out:
# '25M'

# %%
app_reviews.iloc[-5:]
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ## loc

# %%
app_reviews.loc[:5, ['App', 'Size', 'Genres']]
# Out:
#                                                  App  Size  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook   19M
# 1                                Coloring book moana   14M
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  8.7M
# 3                              Sketch - Draw & Paint   25M
# 4              Pixel Draw - Number Art Coloring Book  2.8M
# 5                         Paper flowers instructions  5.6M
#
#                       Genres
# 0               Art & Design
# 1  Art & Design;Pretend Play
# 2               Art & Design
# 3               Art & Design
# 4    Art & Design;Creativity
# 5               Art & Design

# %% [markdown]
# ### Manipulating the index

# %%
app_reviews2.set_index("Rating")
# Out:
#                    Category Reviews                Size     Installs  Type  \
# Rating
# 4.1          ART_AND_DESIGN     159                 19M      10,000+  Free
# 3.9          ART_AND_DESIGN     967                 14M     500,000+  Free
# 4.7          ART_AND_DESIGN   87510                8.7M   5,000,000+  Free
# 4.5          ART_AND_DESIGN  215644                 25M  50,000,000+  Free
# 4.3          ART_AND_DESIGN     967                2.8M     100,000+  Free
# ...                     ...     ...                 ...          ...   ...
# 4.5                  FAMILY      38                 53M       5,000+  Free
# 5.0                  FAMILY       4                3.6M         100+  Free
# NaN                 MEDICAL       3                9.5M       1,000+  Free
# 4.5     BOOKS_AND_REFERENCE     114  Varies with device       1,000+  Free
# 4.5               LIFESTYLE  398307                 19M  10,000,000+  Free
#
# ...

# %% [markdown]
# ## Selecting

# %%
app_reviews
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
app_reviews.loc[(app_reviews.Rating>=4.3) & (app_reviews.Category == "LIFESTYLE")]
# Out:
#                                                      App   Category  Rating  \
# 1564                              Easy Hair Style Design  LIFESTYLE     4.3
# 1566   Black Wallpaper, AMOLED, Dark Background: Darkify  LIFESTYLE     4.6
# 1567                        Girly Wallpapers Backgrounds  LIFESTYLE     4.4
# 1568                            Chart - Myanmar Keyboard  LIFESTYLE     4.4
# 1569                               Easy Makeup Tutorials  LIFESTYLE     4.3
# ...                                                  ...        ...     ...
# 10644                                  South Florida MLS  LIFESTYLE     4.4
# 10742                              GKPB FP Online Church  LIFESTYLE     5.0
# 10797                              Fuel Rewards® program  LIFESTYLE     4.6
# 10805                                      Scoreboard FR  LIFESTYLE     4.3
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
# ...

# %% [markdown]
# ### isin()

# %%
app_reviews.loc[app_reviews.Category.isin(['LIFESTYLE', 'MEDICAL'])]
# Out:
#                                                      App   Category  Rating  \
# 1562                          Dollhouse Decorating Games  LIFESTYLE     4.1
# 1563                                           metroZONE  LIFESTYLE     4.1
# 1564                              Easy Hair Style Design  LIFESTYLE     4.3
# 1565                      Talking Babsy Baby: Baby Games  LIFESTYLE     4.0
# 1566   Black Wallpaper, AMOLED, Dark Background: Darkify  LIFESTYLE     4.6
# ...                                                  ...        ...     ...
# 10806                                    SnakeBite911 FR    MEDICAL     NaN
# 10808                                 lesparticuliers.fr  LIFESTYLE     NaN
# 10824                                          Cardio-FR    MEDICAL     NaN
# 10838                             Parkinson Exercices FR    MEDICAL     NaN
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
# ...

# %% [markdown]
# ### isnull() ( notnull() )

# %%
app_reviews.loc[app_reviews.Rating.isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# ## Assigning

# %%
app_reviews['index_backwards'] = range(len(app_reviews), 0, -1)
app_reviews[['index_backwards']]
#app_reviews['index_backwards']
# Out:
#        index_backwards
# 0                10841
# 1                10840
# 2                10839
# 3                10838
# 4                10837
# ...                ...
# 10836                5
# 10837                4
# 10838                3
# 10839                2
# 10840                1
#
# [10841 rows x 1 columns]

# %%
app_reviews
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
ex = app_reviews.Category.isin(['LIFESTYLE'])
ex
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: Category, Length: 10841, dtype: bool
